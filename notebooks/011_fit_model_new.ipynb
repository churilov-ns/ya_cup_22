# %%
import os
from collections import defaultdict

import pandas as pd
from sklearn.model_selection import train_test_split

from catboost import CatBoostRanker, Pool

from ya_cup_2022.df import CSVDataFrameHandler, FMPSampler
from ya_cup_2022.df.dto import GeneratorOptions

# %%
ARTISTS_FN = 'track_artists.csv'
TRAIN_FN = '_train_300k'
FMP_WD = 'xxl'
CUTOFF = 200
MAX_SKIP = 3
N_PREV_LIKES = 10
N_FAV_ARTISTS = 5
SAMPLE_SIZE = 200
EXTENDED = True

MAX_USERS = 10000
MAX_ROWS = MAX_USERS * SAMPLE_SIZE
MAX_CHUNKS = 1

EXT_PREFIX = 'ext' if EXTENDED else ''
DF_FN = (
    f'df_'
    f'{TRAIN_FN}_'
    f'{FMP_WD}_'
    f'{CUTOFF}_'
    f'{MAX_SKIP}_'
    f'{EXT_PREFIX}_'
    f'{N_PREV_LIKES}_'
    f'{N_FAV_ARTISTS}_'
    f'{SAMPLE_SIZE}'
)

MODEL_FN = f'catboost_rnk__{DF_FN}'
DF_FN += '.csv'

WD = os.path.join('D:', 'education', 'yaintern', 'yandex_cup_2022', 'data')
WD
# Out:
# 'D:education\\yaintern\\yandex_cup_2022\\data'

# %%
sampler = FMPSampler(
    os.path.join(WD, 'fm', FMP_WD),
    cutoff=CUTOFF,
    max_skip=MAX_SKIP,
    extended=EXTENDED,
)

df = CSVDataFrameHandler(
    filename=os.path.join(WD, DF_FN),
    options=GeneratorOptions(
        n_prev_likes=N_PREV_LIKES,
        n_fav_artists=N_FAV_ARTISTS,
        sample_size=SAMPLE_SIZE),
    add_features=sampler.add_features,
    converter=os.path.join(WD, ARTISTS_FN),
).load_chunked(MAX_ROWS, max_chunks=MAX_CHUNKS)

df.head()
# Out:
# Loading tracks/artists from file D:education\yaintern\yandex_cup_2022\data\track_artists.csv
# Total # of tracks: 483275
# Total # of artists: 56134
#    user_id prev_like_0 prev_like_1 prev_like_2 prev_like_3 prev_like_4  \
# 0        0      466482       98655      405936      178706      218582
# 1        0      466482       98655      405936      178706      218582
# 2        0      466482       98655      405936      178706      218582
# 3        0      466482       98655      405936      178706      218582
# 4        0      466482       98655      405936      178706      218582
#
#   prev_like_5 prev_like_6 prev_like_7 prev_like_8  ... cur_track_id  \
# 0       67565      199956      208051       40199  ...       452615
# 1       67565      199956      208051       40199  ...       128093
# 2       67565      199956      208051       40199  ...       447786
# 3       67565      199956      208051       40199  ...        44094
# 4       67565      199956      208051       40199  ...       369944
#
#   cur_artist_id sampler_rank         f       f_0       f_1       f_2  \
# 0         15780        1.000  0.012936  0.012936  0.000000  0.000000
# 1          3471        0.995  0.010321  0.002156  0.005900  0.001027
# 2         15780        0.990  0.010192  0.010192  0.000000  0.000000
# 3         36803        0.985  0.005441  0.002156  0.002771  0.000514
# 4         36803        0.980  0.005193  0.002940  0.001520  0.000321
#
#         f_3 like   rank
# 0  0.000000    0  0.995
# 1  0.001238    0  0.990
# 2  0.000000    0  0.985
# 3  0.000000    0  0.980
# 4  0.000413    0  0.975
#
# [5 rows x 41 columns]

# %%
cat_features = list()
for i, t in enumerate(df.dtypes):
    if isinstance(t, pd.api.types.CategoricalDtype):
        cat_features.append(df.columns[i])
print(cat_features)
# Out:
# ['prev_like_0', 'prev_like_1', 'prev_like_2', 'prev_like_3', 'prev_like_4', 'prev_like_5', 'prev_like_6', 'prev_like_7', 'prev_like_8', 'prev_like_9', 'prev_artist_0', 'prev_artist_1', 'prev_artist_2', 'prev_artist_3', 'prev_artist_4', 'prev_artist_5', 'prev_artist_6', 'prev_artist_7', 'prev_artist_8', 'prev_artist_9', 'fav_artist_0', 'fav_artist_1', 'fav_artist_2', 'fav_artist_3', 'fav_artist_4', 'cur_track_id', 'cur_artist_id']

# %%
for col in filter(lambda c: c.startswith('fav_artist_'), cat_features):
    aid = col.split('_')[-1]
    df[f'fav_artist_match_{aid}'] = (df['cur_artist_id'] == df[col]).astype(int)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1865608    0
# 1865609    0
# 1865610    0
# 1865611    0
# 1865612    0
# Name: fav_artist_match_0, Length: 1865613, dtype: int32

# %%
def create_pool(df, users, cat_features):
    X = df[df['user_id'].isin(users)].reset_index(drop=True)
    
    pairs = list()
    X['i'] = X.index.values
    likes_ids = X[X['like'] == 1].index.values
    tracks_ids = X[X['like'] != 1].groupby('user_id').agg({'i': list})['i'].values
    for i, js in zip(likes_ids, tracks_ids):
        for j in js:
            pairs.append((i, j))
    
    return Pool(
        data=X.drop(['user_id', 'like', 'i'], axis=1),
        label=X['like'],
        group_id=X['user_id'],
        cat_features=cat_features,
        pairs=pairs,
    )

# %%
unique_users = list(df['user_id'].unique())
u_train, u_valid = train_test_split(
    unique_users, 
    test_size=0.2, 
    random_state=42,
)

train_data = create_pool(df, u_train, cat_features)
valid_data = create_pool(df, u_valid, cat_features)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 8>()
#       1 unique_users = list(df['user_id'].unique())
#       2 u_train, u_valid = train_test_split(
#       3     unique_users,
#       4     test_size=0.2,
#       5     random_state=42,
#       6 )
# ----> 8 train_data = create_pool(df, u_train, cat_features)
#       9 valid_data = create_pool(df, u_valid, cat_features)
#
# Input In [6], in create_pool(df, users, cat_features)
#       9     for j in js:
#      10         pairs.append((i, j))
# ---> 12 return Pool(
#      13     data=X.drop(['user_id', 'like', 'i'], axis=1),
#      14     label=X['like'],
#      15     group_id=X['user_id'],
#      16     cat_features=cat_features,
#      17     pairs=pairs,
#      18 )
#
# File ~\anaconda3\envs\ya_cup_2022\lib\site-packages\catboost\core.py:792, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     786         if isinstance(feature_names, PATH_TYPES):
#     787             raise CatBoostError(
#     788                 "feature_names must be None or have non-string type when the pool is created from "
#     789                 "python objects."
#     790             )
# --> 792         self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#     793                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     794 super(Pool, self).__init__()
#
# File ~\anaconda3\envs\ya_cup_2022\lib\site-packages\catboost\core.py:1419, in Pool._init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1417 if feature_tags is not None:
#    1418     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1419 self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#    1420                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:3954, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4004, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:3820, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:2728, in _catboost._set_features_order_data_pd_data_frame()
#
# File ~\anaconda3\envs\ya_cup_2022\lib\site-packages\pandas\core\frame.py:1270, in DataFrame.items(self)
#    1268 if self.columns.is_unique and hasattr(self, "_item_cache"):
#    1269     for k in self.columns:
# -> 1270         yield k, self._get_item_cache(k)
#    1271 else:
#    1272     for i, k in enumerate(self.columns):
#
# KeyboardInterrupt:

# %%
model = CatBoostRanker(
    loss_function='PairLogitPairwise',
    custom_metric='MRR:top=100',
    eval_metric='MRR:top=100',
    metric_period=15,
    per_float_feature_quantization=[
        '32:border_count=1024',
        '33:border_count=1024',
        '34:border_count=1024',
        '35:border_count=1024',
        '36:border_count=1024',
    ],
    early_stopping_rounds=100,
    use_best_model=True,
    random_state=42, 
    task_type='GPU', 
    devices='0',
)

model.fit(
    train_data, 
    eval_set=valid_data,
    plot=False,
)

# %% [raw]
# for feature, importance in zip(X_train.columns, model.get_feature_importance(train_data)):
#     print(f'{feature}: {importance:.6f}')

# %% [raw]
# y_pred = model.predict(valid_data)
# y_pred

# %% [raw]
# model.save_model(os.path.join(WD, MODEL_FN))
